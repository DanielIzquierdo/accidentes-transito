# %%
import pandas as pd
import numpy as np
from tabulate import tabulate as tb
from datetime import datetime

# %%
df =  pd.read_csv('BDD 01-09 2017.csv')
df.head(10)
# Out:
#   ENTE_CONTROL PROVINCIA     FECHA      HORA  \
# 0          MCU     AZUAY  1/1/2017  03:56:00
# 1          MCU     AZUAY  1/1/2017  08:24:00
# 2          MCU     AZUAY  1/1/2017  09:16:00
# 3          MCU     AZUAY  1/1/2017  12:15:00
# 4          MCU     AZUAY  1/2/2017  10:53:00
# 5          MCU     AZUAY  1/1/2017  15:34:00
# 6          MCU     AZUAY  1/2/2017  12:32:00
# 7          MCU     AZUAY  1/2/2017  23:00:00
# 8          MCU     AZUAY  1/2/2017  19:36:00
# 9          MCU     AZUAY  1/3/2017  15:39:00
#
#                                       CAUSA GENERAL        CLASE FINAL  \
# 0  PRESENCIA DE AGENTES EXTERNOS EN LA VÍA (AGUA,...    ESTRELLAMIENTO
# 1  CONDUCE BAJO LA INFLUENCIA DE ALCOHOL, SUSTANC...    ESTRELLAMIENTO
# 2  NO RESPETAR LAS SEÑALES REGLAMENTARIAS DE TRÁN...    CHOQUE LATERAL
# 3  NO RESPETAR LAS SEÑALES REGLAMENTARIAS DE TRÁN...    ESTRELLAMIENTO
# 4                       DAÑOS MECÁNICOS PREVISIBLES.    CHOQUE LATERAL
# 5  NO CEDER EL DERECHO DE VÍA O PREFERENCIA DE PA...         ATROPELLO
# 6  NO RESPETAR LAS SEÑALES REGLAMENTARIAS DE TRÁN...    ESTRELLAMIENTO
# 7       REALIZAR CAMBIO BRUSCO O INDEBIDO DE CARRIL.    CHOQUE LATERAL
# 8  PEATÓN TRANSITA BAJO INFLUENCIA DE ALCOHOL, SU...         ATROPELLO
# 9  NO MANTENER LA DISTANCIA PRUDENCIAL CON RESPEC...  CHOQUE POSTERIOR
#
#   CONSECUENCIA    ZONA                                    DIRECCION  CANTON  \
# 0           SI  URBANO             HURTADO DE MENDOZA Y GUAPONDELIG  CUENCA
# 1           SI  URBANO        AV. DE LAS AMÉRICAS Y GONZALES SUAREZ  CUENCA
# 2           SI  URBANO                 AV. DE LAS AMÉRICAS Y ESPAÑA  CUENCA
# 3           SI  URBANO  LOS DECIMOS JUEGOS BOLIVARIANOS Y DEL TORIL  CUENCA
# 4           SI  URBANO              OCTAVIO DIAZ Y JUAN JOSE FLORES  CUENCA
# 5           NO   RURAL                                 VÍA AL VALLE  CUENCA
# 6           SI   RURAL                    VÍA AL CARMEN DE SININCAY  CUENCA
# 7           SI  URBANO                10 DE AGOSTO  Y MIGUEL MORENO  CUENCA
# 8           NO  URBANO   AV. DE LAS AMÉRICAS Y PASEO RIO MACHANGARA  CUENCA
# 9           SI  URBANO    AV. DE LAS AMÉRICAS - SECTOR CORAL CENTRO  CUENCA
#
#         PARROQUIA  NUM_FALLECIDO  NUM_LESIONADO Unnamed: 13 Unnamed: 14
# 0     TOTORACOCHA            0.0            0.0         NaN         NaN
# 1      MACHANGARA            0.0            1.0         NaN         NaN
# 2      MACHANGARA            0.0            7.0         NaN         NaN
# 3  HERMANO MIGUEL            0.0            0.0         NaN         NaN
# 4        SAN BLAS            0.0            3.0         NaN         NaN
# 5        EL VALLE            0.0            2.0         NaN         NaN
# 6        SININCAY            0.0            0.0         NaN         NaN
# 7           SUCRE            0.0            3.0         NaN         NaN
# 8  HERMANO MIGUEL            0.0            1.0         NaN         NaN
# 9        YANUNCAY            0.0            0.0         NaN         NaN

# %%
# def hour_12_to_24(hour_12):
#     in_time = datetime.strptime(hour_12, "%I:%M:%S %p")
#     out_time = datetime.strftime(in_time, "%H:%M")
#     return out_time
